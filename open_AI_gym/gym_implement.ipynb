# %% [markdown]
# ## Introduction to GYM library

# %%
import gym
import random
import time

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)

# %%
env.reset()

for _ in range(300):
    action = env.action_space.sample()
    env.step(action)
    env.render()
    
env.close()
# Out:
# /Users/kasra/Anaconda3/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/cartpole.py:160: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   logger.warn(

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)

print('Observation space: ', env.observation_space)
print('Action space: ', env.action_space)
# Out:
# Observation space:  Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# Action space:  Discrete(2)

# %%
print(env.reset())
# Out:
# [-0.01246251  0.04013279  0.01829556  0.01271829]

# %% [markdown]
# ## Testing on a new env

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)
env.reset()
# Out:
# array([ 0.00640944, -0.03997543, -0.00339015,  0.01308044], dtype=float32)

# %%
env.step(0)
# Out:
# (array([ 0.00560993, -0.23504859, -0.00312854,  0.30469182], dtype=float32),
#  1.0,
#  False,
#  {})

# %%
env.reset()

for _ in range(10):
    env.step(0)
    env.render()
    time.sleep(0.4)
    
for _ in range(30):
    env.step(1)
    env.render()
    time.sleep(0.4)
    
env.close()
# Out:
# /Users/kasra/Anaconda3/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/cartpole.py:160: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   logger.warn(

# %% [markdown]
# ## New env

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)
state = env.reset()

for _ in range(200):
    pole_angle = state[2]
    action = 0 if pole_angle < 0 else 1
    action, reward, done, info = env.step(action)
    env.render()
    time.sleep(0.1)
    
env.close()
# Out:
# /Users/kasra/Anaconda3/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/cartpole.py:160: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   logger.warn(
